# %%
print("hi")
# Out:
# hi

# %%
from dotenv import load_dotenv

# %%
from langchain_groq import ChatGroq

# %%
llm=ChatGroq(
    model_name="llama-3.1-8b-instant",
)

# %%
llm.invoke("Hello, world!")
# Out:
# AIMessage(content='Hello, world. Is there something I can help you with?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 39, 'total_tokens': 53, 'completion_time': 0.02932417, 'prompt_time': 0.002855381, 'queue_time': 0.064486604, 'total_time': 0.032179551}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ab04adca7d', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--b238e00e-f50e-4a28-ad6e-a7b0e5bd1f72-0', usage_metadata={'input_tokens': 39, 'output_tokens': 14, 'total_tokens': 53})

# %%
from langchain.tools import tool

# %%
from langchain_core.tools import StructuredTool

# %%
class WeatherInput(BaseModel):
    city: str
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 class WeatherInput(BaseModel):
#       2     city: str
#
# NameError: name 'BaseModel' is not defined

# %%
def get_weather(city: str) -> str:
    """
    Get the weather for a given city.

    Args:
        city (str): The name of the city.

    Returns:
        str: A string describing the weather in the city.
    """
    return f"The weather in {city} is sunny."

# %%
weather_tool = StructuredTool.from_function(
    func=get_weather,
    name="get_weather",
    description="Fetches real-time weather data for a city",
    args_schema=WeatherInput,  
)

# %%
class WeatherInput(BaseModel):
    city: str = Field(..., description="City name")
    units: str = Field("metric", description="metric or imperial")

class GetWeatherTool(StructuredTool):
    name: ClassVar[str] = "get_weather"           
    description: ClassVar[str] = (
        "Fetches weather data for a city"
    )
    args_schema: ClassVar[Type[BaseModel]] = WeatherInput

    def _run(self, city: str, units: str = "metric") -> str:
        return get_weather(city, units)
